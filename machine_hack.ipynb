# %% [markdown]
# <a href="https://colab.research.google.com/github/KeeganFernandesWork/machine_hack/blob/main/machine_hack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !git clone https://github.com/KeeganFernandesWork/machine_hack.git

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("machine_hack/train.csv")
test = pd.read_csv("machine_hack/test.csv")
submission = pd.read_csv("machine_hack/submission.csv")
train
# Out:
#        orderID            orderTime                            userID  \
# 0         3829  2015-02-17 15:49:32  37aa37a3d4db63cfedbf976daddebf5c
# 1         4805  2015-02-25 20:28:10  a8336131974a67f838d998609c0e2604
# 2         1658  2015-02-28 23:30:58  f929ef735361e29928150e526255e4a4
# 3         2029  2015-01-28 15:28:08  0ceee2ae489c5c68a483c0c3cd6d9b54
# 4         4703  2015-02-25 11:22:34  2cb1dc0de7a4be59f58d87fdefa91a59
# ...        ...                  ...                               ...
# 11682     2607  2015-01-21 00:04:23  fc406ae38489f024fe86d661cc7f4be5
# 11683     1475  2015-01-20 22:39:52  5b0264b8b02a78bd3fdad7ca31fdb60a
# 11684     2722  2015-02-26 11:20:30  e481f5b99d13beb378d7b98bc4053589
# 11685     1124  2015-01-16 10:50:56  7b088b1590ded8fb040d8554a5b48efe
# 11686       99  2015-02-13 16:09:42  7703816939607808b4052b0e50196c2c
#
#                                couponID      price  basePrice    reward  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11687 entries, 0 to 11686
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   orderID         11687 non-null  int64
#  1   orderTime       11687 non-null  object
#  2   userID          11687 non-null  object
#  3   couponID        11687 non-null  object
#  4   price           11687 non-null  float64
#  5   basePrice       11687 non-null  float64
#  6   reward          11687 non-null  float64
#  7   premiumProduct  11687 non-null  int64
#  8   productGroup    11687 non-null  object
#  9   categoryIDs     11687 non-null  object
#  10  couponUsed      11687 non-null  int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 1004.5+ KB

# %% [markdown]
# Output feature: couponUsed : It is an binary category which contains the information wether the client has redeemed the coupon
#
# Input Features:
#
# orderID : Order unique identification number</br>
# orderTime : The time of order placed</br>
# userID : The unique identification number of the customer</br>
# couponID : Identifier for the coupon</br>
# price : Current price of the coupon</br>
# basePrice : Original price of the coupon</br>
# reward : Score value for the value-added of the product of the retailer</brn>
# premiumProduct : Indicator whether the coupon product is a premium product</br>
# brand : Brand of the coupon product</br>
# productGroup : Product line of the coupon product</br>
# categoryIDs : Identifier of the categories of the coupon product</br>
# couponUsed : Indicator for the coupon which is redeemed 0 (did not redeem) and 1(did redeem).</br>
